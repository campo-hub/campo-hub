# %% [markdown]
# # Git Publish Diagnosis and Fix
#
# This notebook inspects the repository state, removes the reserved Windows path file, and completes the Git publish setup.

# %%
import os
from pathlib import Path

root = Path(r"c:\Users\john\OneDrive\Desktop\everything campus")
print('root exists', root.exists())
print('working dir', Path.cwd())
print('git dir exists', (root / '.git').exists())
print('backend dir exists', (root / 'backend').exists())
print('backend contents:', [p.name for p in (root / 'backend').iterdir()])
